# %%
import csv
import numpy as np
import copy
import random

# %%
def loadDataset(filename):
    with open(filename, 'r') as f:
        lines = csv.reader(f)
        data_set = list(lines)
    offset = 1 if 'test' in filename else 0
    # 整理数据
    for i in range(len(data_set)):
        del(data_set[i][0])
        del(data_set[i][3-1-offset])
        data_set[i][6-2-offset] += data_set[i][7-2-offset]
        del(data_set[i][7-2-offset])
        del(data_set[i][8-3-offset])
        del(data_set[i][10-4-offset])
        del(data_set[i][11-5-offset])
        if 'train' in filename:
            survived = data_set[i].pop(0)
            data_set[i].append(survived)

    category = data_set[0]
    del (data_set[0])
    
    #留下的特征
    # 训练集：['Pclass', 'Sex', 'Age', 'SibSpParch', 'Fare', 'Survived']
    # "Age"有缺项
    # 测试集：['Pclass', 'Sex', 'Age', 'SibSpParch', 'Fare']
    # "Age"&"Fare"有缺项
    # 转换数据格式
    for data in data_set:
        pclass = int(data[0])
        # male : 1, female : 0
        sex = 1 if data[1] == 'male' else 0
        age = int(float(data[2])) if data[2] != '' else 28
        sibspparch = float(data[3][0])+float(data[3][1])
        fare = float(data[4]) if data[4] != '' else 0
        # 补全缺失值 转换记录方式 分类
        # age <25 为0, 25<=age<60为1，age>=60为2
        if age < 25:
            age = 0
        elif age >= 25 and age < 60: 
            age = 1
        else:
            age = 2
        # sibsp&parch以2为界限，小于为0，大于为1
        if sibspparch < 2:
            sibspparch = 0
        else:
            sibspparch = 1
        # fare以64为界限
        if fare < 64:
            fare = 0
        else:
            fare = 1
        #更新数据
        data[0] = pclass 
        data[1] = sex
        data[2] = age
        data[3] = sibspparch
        data[4] = fare

        if 'train' in filename:
            data[-1] = int(data[-1])
            
    return data_set, category

def split_data(data):

    data_set = copy.deepcopy(data)

    data_mat = []
    label_mat = []
    for i in range(len(data_set)):
        if data_set[i][-1] == 0:
            data_set[i][-1] = -1

        label_mat.append(data_set[i][-1])
        del(data_set[i][-1])
        data_mat.append(data_set[i])

    return data_mat, label_mat

# %%
def select_j(i ,m):
    # 选取alpha
    j = i
    while j == i:
        j = int(random.uniform(0, m))
    return j

def clip_alpha(aj, H, L):
    # 修剪alpha
    if aj > H:
        aj = H
    if L > aj:
        aj = L

    return aj

# %%
class SVMclassifier(object):
    def __init__(self, kTup):
        self.kTup = kTup
    
    def kernelTrans(self, X, A, kTup): #通过数据计算转换后的核函数
        m = np.shape(X)[0]
        kappa = np.mat(np.zeros((m,1)))
        
        if kTup[0]=='linear': 
            #线性核函数
            kappa = X * A.T   
    
        elif kTup[0]=='rbf':
            #高斯核
            for j in range(m):
                delta_row = X[j,:] - A
                kappa[j] = delta_row * delta_row.T
            kappa = np.exp(kappa/(-1*kTup[1]**2)) 
 
        elif kTup[0] == 'laplace':
            #拉普拉斯核
            for j in range(m):
                delta_row = X[j,:] - A
                kappa[j] = delta_row*delta_row.T
                kappa[j] = np.sqrt(kappa[j])
            kappa = np.exp(-kappa/kTup[1])     
 
        elif kTup[0] == 'poly':
            #多项式核
            kappa = X * A.T
            for j in range(m):
                kappa[j] = kappa[j]**kTup[1]
        
        elif kTup[0] == 'sigmoid':
            #Sigmoid核
            kappa = X * A.T
            for j in range(m):
                kappa[j] = np.tanh(kTup[1]*kappa[j]+kTup[2])
        
        return kappa
    
    def smo(self, data_mat_In, class_label, C, toler, max_iter_num):
        # 转化为numpy的mat存储
        data_matrix = np.mat(data_mat_In)
        label_mat = np.mat(class_label).transpose()
        
        # 初始化b，统计data_matrix的维度
        b = 0
        m = np.shape(data_matrix)[0]
        # 初始化alpha，设为0
        alphas = np.mat(np.zeros((m, 1)))
        
        # 初始化迭代次数
        iter_num = 0
        alpha_pairs_changed = 0
        entire_set = True
        # 最多迭代max_iter次
        while iter_num <= max_iter_num and ((alpha_pairs_changed > 0) or (entire_set)):
            alpha_pairs_changed = 0
            if entire_set and (iter_num <= max_iter_num):
                for i in range(m):
                    # 计算误差error_i
                    fxi = float(np.multiply(alphas, label_mat).T*(self.kernelTrans(data_matrix, data_matrix[i,:], self.kTup))) + b
                    error_i = fxi - float(label_mat[i])
                    # 优化alpha，松弛向量
                    if (label_mat[i]*error_i < -toler and alphas[i] < C) or (label_mat[i]*error_i > toler and alphas[i] > 0):
                        # 随机选取另一个与alpha_j成对优化的alpha_j
                        j = select_j(i, m)
                        # 1.计算误差error_j
                        fxj = float(np.multiply(alphas, label_mat).T*(self.kernelTrans(data_matrix, data_matrix[j,:], self.kTup))) + b
                        error_j = fxj - float(label_mat[j])
                        # 保存更新前的alpha，deepcopy
                        alpha_i_old = copy.deepcopy(alphas[i])
                        alpha_j_old = copy.deepcopy(alphas[j])
                        # 2.计算上下界L和H
                        if label_mat[i] != label_mat[j]:
                            L = max(0, alphas[j] - alphas[i])
                            H = min(C, C + alphas[j] - alphas[i])
                        else:
                            L = max(0, alphas[j] + alphas[i] - C)
                            H = min(C, alphas[j] + alphas[i])
                        if L == H:
                            print("L == H")
                            continue
                        # 3.计算eta
                        eta = data_matrix[i, :]*data_matrix[j, :].T - data_matrix[i, :]*data_matrix[i, :].T - data_matrix[j, :]*data_matrix[j, :].T
                        if eta >= 0:
                            print("eta >= 0")
                            continue
                        # 4.更新alpha_j
                        alphas[j] -= label_mat[j]*(error_i - error_j)/eta
                        # 5.修剪alpha_j
                        alphas[j] = clip_alpha(alphas[j], H, L)
                        if abs(alphas[j] - alphas[i]) < 1e-5:
                            print("alpha_j变化太小")
                            continue
                        # 6.更新alpha_i
                        alphas[i] += label_mat[j]*label_mat[i]*(alpha_j_old - alphas[j])
                        # 7.更新b_1和b_2
                        b_1 = b - error_i - label_mat[i]*(alphas[i] - alpha_i_old)*data_matrix[i, :]*data_matrix[i, :].T - label_mat[j]*(alphas[j] - alpha_j_old)*data_matrix[i, :]*data_matrix[j, :].T
                        b_2 = b - error_j - label_mat[i]*(alphas[i] - alpha_i_old)*data_matrix[i, :]*data_matrix[j, :].T - label_mat[j]*(alphas[j] - alpha_j_old)*data_matrix[j, :] * data_matrix[j, :].T
                        # 8.根据b_1和b_2更新b
                        if 0 < alphas[i] and C > alphas[i]:
                            b = b_1
                        elif 0 < alphas[j] and C > alphas[j]:
                            b = b_2
                        else:
                            b = (b_1 + b_2)/2
                        # 统计优化次数
                        alpha_pairs_changed += 1
                        # 打印统计信息
                        print("full-set 样本：%d , alpha优化次数：%d" % (i, alpha_pairs_changed))
                iter_num += 1
                
            elif(iter_num <= max_iter_num):
                non_bound = np.nonzero((alphas[i] > 0) * (alphas[i] < C))[0]
                for i in non_bound:
                    if (label_mat[i]*error_i < -toler and alphas[i] < C) or (label_mat[i]*error_i > toler and alphas[i] > 0):
                        alpha_pairs_changed += 1
                    print ("non-bound 样本：%d , alpha优化次数：%d" % (i,alpha_pairs_changed))
                iter_num += 1
                
            if entire_set: 
                entire_set = False 
            elif (alpha_pairs_changed == 0): 
                entire_set = True  
            print ("迭代次数: %d" % iter_num)

        return b, alphas
    
    def prediction(self, test, w, b):
        test = np.mat(test)
        result = []
        for i in test:
            if i * w + b > 0:
                result.append(1)
            else:
                result.append(-1)

        return result
    
    def compute_w(self, data_mat, label_mat, alphas):
        # 计算w
        alphas = np.array(alphas)
        data_mat = np.array(data_mat)
        label_mat = np.array(label_mat)

        w = np.dot((np.tile(label_mat.reshape(1, -1).T, (1, 5))*data_mat).T, alphas)
        return w.tolist()

# %%
if __name__ == "__main__":
    data_set, category_train = loadDataset('train.csv')

    data_mat, label_mat = split_data(data_set)

    test_mat = data_mat[:800]
    test_label = label_mat[:800]
    data_mat = data_mat[800:]
    label_mat = label_mat[800:]
    
    linear_classifier = SVMclassifier(kTup=['linear'])
    
    #训练
    b, alphas = linear_classifier.smo(data_mat, label_mat, 0.5, 1e-3, 200)

    w = linear_classifier.compute_w(data_mat, label_mat, alphas)

    result = linear_classifier.prediction(test_mat, w, b)

    count = 0
    survived = 0
    
    #准确率
    for i in range(len(result)):
        if result[i] == test_label[i]:
            count += 1
    #训练集存活率
    for i in range(len(data_mat)):
        if label_mat[i] == 1:
            survived += 1
    
    print('Survive rate in training set:'+str(survived/len(data_mat)*100)+'%')
    print('Accuracy:'+str(count/len(result)*100)+'%')
# Out:
# full-set 样本：0 , alpha优化次数：1
# full-set 样本：1 , alpha优化次数：2
# full-set 样本：3 , alpha优化次数：3
# full-set 样本：4 , alpha优化次数：4
# L == H
# L == H
# full-set 样本：7 , alpha优化次数：5
# L == H
# full-set 样本：9 , alpha优化次数：6
# L == H
# L == H
# full-set 样本：12 , alpha优化次数：7
# L == H
# full-set 样本：15 , alpha优化次数：8
# full-set 样本：16 , alpha优化次数：9
# full-set 样本：20 , alpha优化次数：10
# full-set 样本：21 , alpha优化次数：11
# full-set 样本：22 , alpha优化次数：12
# L == H
# full-set 样本：24 , alpha优化次数：13
# full-set 样本：27 , alpha优化次数：14
# full-set 样本：28 , alpha优化次数：15
# L == H
# full-set 样本：33 , alpha优化次数：16
# full-set 样本：35 , alpha优化次数：17
# L == H
# L == H
# L == H
# full-set 样本：39 , alpha优化次数：18
# full-set 样本：40 , alpha优化次数：19
# L == H
# L == H
# full-set 样本：48 , alpha优化次数：20
# full-set 样本：49 , alpha优化次数：21
# L == H
# L == H
# full-set 样本：54 , alpha优化次数：22
# full-set 样本：55 , alpha优化次数：23
# full-set 样本：58 , alpha优化次数：24
# full-set 样本：60 , alpha优化次数：25
# full-set 样本：61 , alpha优化次数：26
# full-set 样本：62 , alpha优化次数：27
# full-set 样本：63 , alpha优化次数：28
# full-set 样本：65 , alpha优化次数：29
# L == H
# full-set 样本：69 , alpha优化次数：30
# full-set 样本：70 , alpha优化次数：31
# L == H
# full-set 样本：74 , alpha优化次数：32
# full-set 样本：75 , alpha优化次数：33
# full-set 样本：76 , alpha优化次数：34
# full-set 样本：80 , alpha优化次数：35
# full-set 样本：81 , alpha优化次数：36
# alpha_j变化太小
# full-set 样本：83 , alpha优化次数：37
# L == H
# full-set 样本：87 , alpha优化次数：38
# full-set 样本：88 , alpha优化次数：39
# alpha_j变化太小
# 迭代次数: 1
# 迭代次数: 2
# full-set 样本：0 , alpha优化次数：1
# full-set 样本：4 , alpha优化次数：2
# L == H
# full-set 样本：6 , alpha优化次数：3
# full-set 样本：7 , alpha优化次数：4
# full-set 样本：9 , alpha优化次数：5
# full-set 样本：12 , alpha优化次数：6
# full-set 样本：13 , alpha优化次数：7
# full-set 样本：15 , alpha优化次数：8
# full-set 样本：16 , alpha优化次数：9
# L == H
# full-set 样本：18 , alpha优化次数：10
# full-set 样本：19 , alpha优化次数：11
# alpha_j变化太小
# full-set 样本：21 , alpha优化次数：12
# full-set 样本：22 , alpha优化次数：13
# full-set 样本：23 , alpha优化次数：14
# full-set 样本：24 , alpha优化次数：15
# full-set 样本：28 , alpha优化次数：16
# full-set 样本：30 , alpha优化次数：17
# full-set 样本：31 , alpha优化次数：18
# L == H
# full-set 样本：33 , alpha优化次数：19
# full-set 样本：34 , alpha优化次数：20
# full-set 样本：35 , alpha优化次数：21
# L == H
# full-set 样本：37 , alpha优化次数：22
# full-set 样本：38 , alpha优化次数：23
# alpha_j变化太小
# full-set 样本：40 , alpha优化次数：24
# full-set 样本：42 , alpha优化次数：25
# L == H
# full-set 样本：44 , alpha优化次数：26
# full-set 样本：45 , alpha优化次数：27
# full-set 样本：46 , alpha优化次数：28
# full-set 样本：48 , alpha优化次数：29
# full-set 样本：49 , alpha优化次数：30
# full-set 样本：50 , alpha优化次数：31
# full-set 样本：51 , alpha优化次数：32
# full-set 样本：52 , alpha优化次数：33
# full-set 样本：55 , alpha优化次数：34
# full-set 样本：57 , alpha优化次数：35
# full-set 样本：58 , alpha优化次数：36
# full-set 样本：59 , alpha优化次数：37
# full-set 样本：61 , alpha优化次数：38
# full-set 样本：62 , alpha优化次数：39
# full-set 样本：63 , alpha优化次数：40
# full-set 样本：64 , alpha优化次数：41
# full-set 样本：65 , alpha优化次数：42
# full-set 样本：67 , alpha优化次数：43
# full-set 样本：69 , alpha优化次数：44
# full-set 样本：70 , alpha优化次数：45
# full-set 样本：71 , alpha优化次数：46
# full-set 样本：74 , alpha优化次数：47
# full-set 样本：75 , alpha优化次数：48
# full-set 样本：76 , alpha优化次数：49
# L == H
# full-set 样本：79 , alpha优化次数：50
# full-set 样本：80 , alpha优化次数：51
# full-set 样本：81 , alpha优化次数：52
# alpha_j变化太小
# full-set 样本：83 , alpha优化次数：53
# full-set 样本：85 , alpha优化次数：54
# full-set 样本：86 , alpha优化次数：55
# full-set 样本：87 , alpha优化次数：56
# full-set 样本：88 , alpha优化次数：57
# full-set 样本：89 , alpha优化次数：58
# full-set 样本：90 , alpha优化次数：59
# 迭代次数: 3
# 迭代次数: 4
# full-set 样本：1 , alpha优化次数：1
# full-set 样本：2 , alpha优化次数：2
# full-set 样本：4 , alpha优化次数：3
# full-set 样本：6 , alpha优化次数：4
# full-set 样本：7 , alpha优化次数：5
# full-set 样本：9 , alpha优化次数：6
# full-set 样本：10 , alpha优化次数：7
# full-set 样本：12 , alpha优化次数：8
# full-set 样本：13 , alpha优化次数：9
# full-set 样本：15 , alpha优化次数：10
# full-set 样本：16 , alpha优化次数：11
# full-set 样本：17 , alpha优化次数：12
# full-set 样本：18 , alpha优化次数：13
# full-set 样本：19 , alpha优化次数：14
# full-set 样本：20 , alpha优化次数：15
# full-set 样本：22 , alpha优化次数：16
# full-set 样本：23 , alpha优化次数：17
# full-set 样本：24 , alpha优化次数：18
# full-set 样本：27 , alpha优化次数：19
# full-set 样本：28 , alpha优化次数：20
# full-set 样本：29 , alpha优化次数：21
# full-set 样本：30 , alpha优化次数：22
# full-set 样本：31 , alpha优化次数：23
# full-set 样本：32 , alpha优化次数：24
# full-set 样本：34 , alpha优化次数：25
# full-set 样本：37 , alpha优化次数：26
# full-set 样本：39 , alpha优化次数：27
# full-set 样本：41 , alpha优化次数：28
# full-set 样本：42 , alpha优化次数：29
# full-set 样本：44 , alpha优化次数：30
# full-set 样本：45 , alpha优化次数：31
# full-set 样本：46 , alpha优化次数：32
# full-set 样本：48 , alpha优化次数：33
# full-set 样本：49 , alpha优化次数：34
# full-set 样本：50 , alpha优化次数：35
# full-set 样本：51 , alpha优化次数：36
# full-set 样本：52 , alpha优化次数：37
# full-set 样本：55 , alpha优化次数：38
# full-set 样本：57 , alpha优化次数：39
# full-set 样本：58 , alpha优化次数：40
# full-set 样本：59 , alpha优化次数：41
# full-set 样本：60 , alpha优化次数：42
# full-set 样本：62 , alpha优化次数：43
# full-set 样本：64 , alpha优化次数：44
# full-set 样本：65 , alpha优化次数：45
# full-set 样本：66 , alpha优化次数：46
# full-set 样本：69 , alpha优化次数：47
# alpha_j变化太小
# full-set 样本：71 , alpha优化次数：48
# full-set 样本：72 , alpha优化次数：49
# full-set 样本：74 , alpha优化次数：50
# full-set 样本：75 , alpha优化次数：51
# L == H
# full-set 样本：77 , alpha优化次数：52
# full-set 样本：79 , alpha优化次数：53
# L == H
# full-set 样本：81 , alpha优化次数：54
# full-set 样本：82 , alpha优化次数：55
# full-set 样本：83 , alpha优化次数：56
# full-set 样本：85 , alpha优化次数：57
# full-set 样本：87 , alpha优化次数：58
# full-set 样本：88 , alpha优化次数：59
# full-set 样本：89 , alpha优化次数：60
# full-set 样本：90 , alpha优化次数：61
# 迭代次数: 5
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 6
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 7
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 8
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 9
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 10
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 11
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 12
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 13
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 14
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 15
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 16
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 17
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 18
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 19
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 20
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 21
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 22
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 23
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 24
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 25
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 26
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 27
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 28
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 29
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 30
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 31
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 32
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 33
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 34
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 35
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 36
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 37
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 38
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 39
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 40
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 41
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 42
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 43
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 44
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 45
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 46
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 47
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 48
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 49
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 50
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 51
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 52
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 53
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 54
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 55
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 56
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 57
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 58
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 59
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 60
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 61
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 62
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 63
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 64
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 65
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 66
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 67
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 68
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 69
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 70
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 71
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 72
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 73
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 74
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 75
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 76
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 77
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 78
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 79
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 80
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 81
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 82
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 83
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 84
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 85
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 86
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 87
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 88
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 89
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 90
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 91
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 92
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 93
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 94
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 95
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 96
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 97
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 98
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 99
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 100
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 101
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 102
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 103
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 104
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 105
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 106
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 107
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 108
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 109
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 110
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 111
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 112
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 113
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 114
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 115
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 116
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 117
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 118
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 119
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 120
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 121
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 122
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 123
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 124
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 125
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 126
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 127
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 128
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 129
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 130
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 131
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 132
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 133
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 134
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 135
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 136
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 137
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 138
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 139
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 140
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 141
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 142
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 143
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 144
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 145
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 146
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 147
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 148
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 149
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 150
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 151
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 152
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 153
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 154
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 155
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 156
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 157
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 158
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 159
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 160
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 161
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 162
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 163
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 164
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 165
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 166
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 167
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 168
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 169
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 170
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 171
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 172
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 173
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 174
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 175
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 176
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 177
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 178
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 179
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 180
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 181
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 182
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 183
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 184
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 185
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 186
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 187
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 188
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 189
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 190
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 191
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 192
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 193
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 194
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 195
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 196
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 197
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 198
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 199
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 200
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 201
# survive_rate_in_training_set:37.362637362637365%
# accuracy:75.375%

# %%
if __name__ == "__main__":
    
    Gaussian_classifier = SVMclassifier(kTup=['rbf', 1.5])
    
    #训练
    b, alphas = Gaussian_classifier.smo(data_mat, label_mat, 0.5, 1e-3, 200)

    w = Gaussian_classifier.compute_w(data_mat, label_mat, alphas)

    result = Gaussian_classifier.prediction(test_mat, w, b)

    count = 0
    survived = 0
    
    #准确率
    for i in range(len(result)):
        if result[i] == test_label[i]:
            count += 1
    #训练集存活率
    for i in range(len(data_mat)):
        if label_mat[i] == 1:
            survived += 1
    
    print('Survive rate in training set:'+str(survived/len(data_mat)*100)+'%')
    print('Accuracy:'+str(count/len(result)*100)+'%')
# Out:
# L == H
# full-set 样本：1 , alpha优化次数：1
# L == H
# full-set 样本：4 , alpha优化次数：2
# full-set 样本：5 , alpha优化次数：3
# full-set 样本：6 , alpha优化次数：4
# full-set 样本：7 , alpha优化次数：5
# full-set 样本：9 , alpha优化次数：6
# L == H
# L == H
# full-set 样本：12 , alpha优化次数：7
# L == H
# L == H
# full-set 样本：15 , alpha优化次数：8
# L == H
# full-set 样本：21 , alpha优化次数：9
# full-set 样本：22 , alpha优化次数：10
# full-set 样本：23 , alpha优化次数：11
# L == H
# full-set 样本：25 , alpha优化次数：12
# full-set 样本：26 , alpha优化次数：13
# full-set 样本：27 , alpha优化次数：14
# L == H
# full-set 样本：33 , alpha优化次数：15
# L == H
# full-set 样本：35 , alpha优化次数：16
# L == H
# full-set 样本：37 , alpha优化次数：17
# full-set 样本：38 , alpha优化次数：18
# alpha_j变化太小
# L == H
# L == H
# full-set 样本：42 , alpha优化次数：19
# L == H
# L == H
# full-set 样本：45 , alpha优化次数：20
# L == H
# full-set 样本：47 , alpha优化次数：21
# full-set 样本：48 , alpha优化次数：22
# L == H
# full-set 样本：50 , alpha优化次数：23
# full-set 样本：52 , alpha优化次数：24
# L == H
# L == H
# L == H
# full-set 样本：57 , alpha优化次数：25
# full-set 样本：59 , alpha优化次数：26
# L == H
# L == H
# full-set 样本：62 , alpha优化次数：27
# L == H
# L == H
# full-set 样本：67 , alpha优化次数：28
# full-set 样本：69 , alpha优化次数：29
# full-set 样本：70 , alpha优化次数：30
# L == H
# full-set 样本：73 , alpha优化次数：31
# full-set 样本：74 , alpha优化次数：32
# full-set 样本：75 , alpha优化次数：33
# full-set 样本：76 , alpha优化次数：34
# L == H
# L == H
# full-set 样本：79 , alpha优化次数：35
# full-set 样本：80 , alpha优化次数：36
# L == H
# full-set 样本：82 , alpha优化次数：37
# full-set 样本：83 , alpha优化次数：38
# full-set 样本：84 , alpha优化次数：39
# full-set 样本：85 , alpha优化次数：40
# full-set 样本：87 , alpha优化次数：41
# full-set 样本：88 , alpha优化次数：42
# full-set 样本：89 , alpha优化次数：43
# alpha_j变化太小
# 迭代次数: 1
# 迭代次数: 2
# full-set 样本：0 , alpha优化次数：1
# full-set 样本：1 , alpha优化次数：2
# full-set 样本：2 , alpha优化次数：3
# full-set 样本：3 , alpha优化次数：4
# full-set 样本：4 , alpha优化次数：5
# full-set 样本：5 , alpha优化次数：6
# full-set 样本：7 , alpha优化次数：7
# full-set 样本：9 , alpha优化次数：8
# full-set 样本：10 , alpha优化次数：9
# L == H
# full-set 样本：12 , alpha优化次数：10
# L == H
# full-set 样本：16 , alpha优化次数：11
# full-set 样本：20 , alpha优化次数：12
# full-set 样本：21 , alpha优化次数：13
# full-set 样本：22 , alpha优化次数：14
# full-set 样本：23 , alpha优化次数：15
# full-set 样本：24 , alpha优化次数：16
# full-set 样本：25 , alpha优化次数：17
# full-set 样本：26 , alpha优化次数：18
# full-set 样本：27 , alpha优化次数：19
# full-set 样本：28 , alpha优化次数：20
# full-set 样本：29 , alpha优化次数：21
# full-set 样本：30 , alpha优化次数：22
# full-set 样本：31 , alpha优化次数：23
# full-set 样本：32 , alpha优化次数：24
# full-set 样本：33 , alpha优化次数：25
# full-set 样本：34 , alpha优化次数：26
# full-set 样本：35 , alpha优化次数：27
# full-set 样本：36 , alpha优化次数：28
# full-set 样本：38 , alpha优化次数：29
# full-set 样本：40 , alpha优化次数：30
# full-set 样本：41 , alpha优化次数：31
# full-set 样本：42 , alpha优化次数：32
# full-set 样本：43 , alpha优化次数：33
# full-set 样本：44 , alpha优化次数：34
# full-set 样本：45 , alpha优化次数：35
# full-set 样本：46 , alpha优化次数：36
# full-set 样本：47 , alpha优化次数：37
# full-set 样本：48 , alpha优化次数：38
# full-set 样本：49 , alpha优化次数：39
# full-set 样本：50 , alpha优化次数：40
# full-set 样本：51 , alpha优化次数：41
# full-set 样本：52 , alpha优化次数：42
# L == H
# full-set 样本：55 , alpha优化次数：43
# full-set 样本：56 , alpha优化次数：44
# full-set 样本：57 , alpha优化次数：45
# full-set 样本：59 , alpha优化次数：46
# full-set 样本：60 , alpha优化次数：47
# full-set 样本：61 , alpha优化次数：48
# full-set 样本：62 , alpha优化次数：49
# full-set 样本：63 , alpha优化次数：50
# full-set 样本：65 , alpha优化次数：51
# full-set 样本：67 , alpha优化次数：52
# full-set 样本：71 , alpha优化次数：53
# full-set 样本：72 , alpha优化次数：54
# full-set 样本：73 , alpha优化次数：55
# L == H
# L == H
# full-set 样本：76 , alpha优化次数：56
# full-set 样本：78 , alpha优化次数：57
# full-set 样本：79 , alpha优化次数：58
# full-set 样本：80 , alpha优化次数：59
# full-set 样本：81 , alpha优化次数：60
# full-set 样本：82 , alpha优化次数：61
# full-set 样本：83 , alpha优化次数：62
# full-set 样本：84 , alpha优化次数：63
# full-set 样本：85 , alpha优化次数：64
# full-set 样本：86 , alpha优化次数：65
# full-set 样本：87 , alpha优化次数：66
# full-set 样本：88 , alpha优化次数：67
# full-set 样本：89 , alpha优化次数：68
# full-set 样本：90 , alpha优化次数：69
# 迭代次数: 3
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 4
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 5
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 6
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 7
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 8
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 9
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 10
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 11
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 12
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 13
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 14
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 15
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 16
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 17
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 18
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 19
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 20
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 21
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 22
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 23
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 24
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 25
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 26
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 27
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 28
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 29
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 30
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 31
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 32
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 33
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 34
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 35
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 36
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 37
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 38
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 39
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 40
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 41
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 42
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 43
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 44
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 45
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 46
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 47
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 48
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 49
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 50
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 51
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 52
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 53
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 54
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 55
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 56
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 57
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 58
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 59
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 60
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 61
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 62
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 63
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 64
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 65
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 66
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 67
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 68
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 69
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 70
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 71
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 72
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 73
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 74
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 75
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 76
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 77
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 78
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 79
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 80
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 81
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 82
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 83
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 84
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 85
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 86
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 87
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 88
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 89
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 90
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 91
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 92
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 93
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 94
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 95
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 96
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 97
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 98
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 99
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 100
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 101
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 102
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 103
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 104
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 105
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 106
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 107
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 108
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 109
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 110
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 111
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 112
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 113
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 114
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 115
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 116
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 117
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 118
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 119
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 120
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 121
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 122
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 123
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 124
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 125
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 126
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 127
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 128
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 129
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 130
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 131
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 132
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 133
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 134
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 135
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 136
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 137
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 138
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 139
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 140
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 141
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 142
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 143
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 144
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 145
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 146
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 147
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 148
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 149
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 150
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 151
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 152
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 153
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 154
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 155
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 156
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 157
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 158
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 159
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 160
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 161
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 162
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 163
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 164
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 165
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 166
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 167
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 168
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 169
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 170
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 171
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 172
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 173
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 174
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 175
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 176
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 177
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 178
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 179
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 180
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 181
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 182
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 183
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 184
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 185
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 186
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 187
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 188
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 189
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 190
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 191
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 192
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 193
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 194
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 195
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 196
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 197
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 198
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 199
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 200
# non-bound 样本：0 , alpha优化次数：1
# 迭代次数: 201
# survive_rate_in_training_set:37.362637362637365%
# accuracy:61.5%
